# %%
# !pip install langchain langchain-community langchain-core langchain-ollama
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_ollama import OllamaLLM,OllamaEmbeddings
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.vectorstores import InMemoryVectorStore

# %%
docs = [
"LangChain is a framework designed to simplify the creation of applications using large language models.",
"Ollama allows you to run open-source large language models locally on your machine.",
"RAG (Retrieval-Augmented Generation) optimizes LLM output by referencing an authoritative knowledge base outside of its training data."
]

# %%
# 2. Embeddings & Vector Store (Replaces all NumPy math)
embeddings = OllamaEmbeddings(model="mxbai-embed-large")
vectorstore = InMemoryVectorStore.from_texts(docs, embedding=embeddings)
retriever = vectorstore.as_retriever(search_kwargs={"k": 1})

# %%
llm=OllamaLLM(model="llama3.2:1b",temperature=.7,max_tokens=256)

# %%
# 3.Prompt Template (Clean & Reusable)
prompt = ChatPromptTemplate.from_messages([
    (
        "system", 
        "Answer the user's question based only on the provided context."
    ),
    (
        "user", 
        "Context: {context}\n\nQuestion: {question}"
    )
])

# %%
output_parser = StrOutputParser()

# %%
chain=prompt | llm | output_parser

# %%
user_query="what is RAG in the context of LLMs?"
docs=retriever.invoke(user_query)

# %%
docs
# Out:
# [Document(id='f7366a47-275c-4af9-9cf7-e42244f67477', metadata={}, page_content='RAG (Retrieval-Augmented Generation) optimizes LLM output by referencing an authoritative knowledge base outside of its training data.')]

# %%
docs[0].page_content
# Out:
# 'RAG (Retrieval-Augmented Generation) optimizes LLM output by referencing an authoritative knowledge base outside of its training data.'

# %%
retrival_page_content="/n/n".join([ doc.page_content for doc in docs ])

# %%
response = chain.invoke({"context":retrival_page_content, "question": user_query})
print(response)
# Out:
# In the context of Large Language Models (LLMs), RAG stands for Retrieval-Augmented Generation. It's a technique that optimizes the output of these models by referencing an authoritative knowledge base, also known as a knowledge graph, outside of their training data. This approach helps LLMs generate more accurate and informative responses by leveraging the knowledge contained in this external knowledge base, which is typically more comprehensive and up-to-date than the training data used to train the model.
